# %% [markdown]
# ![Connectx's logo](<attachment:logo.jpg>)

# %% [markdown]
# # ```Importing libraries & data overview```

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
# Ignore warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("crimes/new_file.csv")

# %%
data.shape
# Out:
# (2214, 147)

# %% [markdown]
# We have 2214 rows and 147 columns

# %%
data.head(5)
# Out:
#       communityname state countyCode communityCode  fold  population  \
# 0    Marpletownship    PA         45         47616     1       23123
# 1        Tigardcity    OR          ?             ?     1       29344
# 2  Gloversvillecity    NY         35         29443     1       16656
# 3       Bemidjicity    MN          7          5068     1       11245
# 4   Springfieldcity    MO          ?             ?     1      140494
#
#    householdsize  racepctblack  racePctWhite  racePctAsian  ...  burglaries  \
# 0           2.82          0.80         95.57          3.44  ...          57
# 1           2.43          0.74         94.33          3.43  ...         274
# 2           2.40          1.70         97.35          0.50  ...         225
# 3           2.76          0.53         89.16          1.17  ...          91
# 4           2.45          2.51         95.65          0.90  ...        2094
#
#    burglPerPop  larcenies  larcPerPop  autoTheft  autoTheftPerPop  arsons  \
# ...

# %% [markdown]
# ## colums description

# %% [markdown]
# -- communityname: Community name - not predictive - for information only (string)
#
# -- state: US state (by 2 letter postal abbreviation)(nominal)
#
# -- countyCode: numeric code for county - not predictive, and many missing values (numeric)
#
# -- communityCode: numeric code for community - not predictive and many missing values (numeric)
#
# -- fold: fold number for non-random 10 fold cross validation, potentially useful for debugging, paired tests - not predictive (numeric - integer)
#
# -- population: population for community: (numeric - expected to be integer)
#
# -- householdsize: mean people per household (numeric - decimal)
#
# -- racepctblack: percentage of population that is african american (numeric - decimal)
#
# -- racePctWhite: percentage of population that is caucasian (numeric - decimal)
#
# -- racePctAsian: percentage of population that is of asian heritage (numeric - decimal)
#
# -- racePctHisp: percentage of population that is of hispanic heritage (numeric - decimal)
#
# -- agePct12t21: percentage of population that is 12-21 in age (numeric - decimal)
#
# -- agePct12t29: percentage of population that is 12-29 in age (numeric - decimal)
#
# -- agePct16t24: percentage of population that is 16-24 in age (numeric - decimal)
#
# -- agePct65up: percentage of population that is 65 and over in age (numeric - decimal)
#
# -- numbUrban: number of people living in areas classified as urban (numeric - expected to be integer)
#
# -- pctUrban: percentage of people living in areas classified as urban (numeric - decimal)
#
# -- medIncome: median household income (numeric - may be integer)
#
# -- pctWWage: percentage of households with wage or salary income in 1989 (numeric - decimal)
#
# -- pctWFarmSelf: percentage of households with farm or self employment income in 1989 (numeric - decimal)
#
# -- pctWInvInc: percentage of households with investment / rent income in 1989 (numeric - decimal)
#
# -- pctWSocSec: percentage of households with social security income in 1989 (numeric - decimal)
#
# -- pctWPubAsst: percentage of households with public assistance income in 1989 (numeric - decimal)
#
# -- pctWRetire: percentage of households with retirement income in 1989 (numeric - decimal)
#
# -- medFamInc: median family income (differs from household income for non-family households) (numeric - may be integer)
#
# -- perCapInc: per capita income (numeric - decimal)
#
# -- whitePerCap: per capita income for caucasians (numeric - decimal)
#
# -- blackPerCap: per capita income for african americans (numeric - decimal)
#
# -- indianPerCap: per capita income for native americans (numeric - decimal)
#
# -- AsianPerCap: per capita income for people with asian heritage (numeric - decimal)
#
# -- OtherPerCap: per capita income for people with 'other' heritage (numeric - decimal)
#
# -- HispPerCap: per capita income for people with hispanic heritage (numeric - decimal)
#
# -- NumUnderPov: number of people under the poverty level (numeric - expected to be integer)
#
# -- PctPopUnderPov: percentage of people under the poverty level (numeric - decimal)
#
# -- PctLess9thGrade: percentage of people 25 and over with less than a 9th grade education (numeric - decimal)
#
# -- PctNotHSGrad: percentage of people 25 and over that are not high school graduates (numeric - decimal)
#
# -- PctBSorMore: percentage of people 25 and over with a bachelors degree or higher education (numeric - decimal)
#
# -- PctUnemployed: percentage of people 16 and over, in the labor force, and unemployed (numeric - decimal)
#
# -- PctEmploy: percentage of people 16 and over who are employed (numeric - decimal)
#
# -- PctEmplManu: percentage of people 16 and over who are employed in manufacturing (numeric - decimal)
#
# -- PctEmplProfServ: percentage of people 16 and over who are employed in professional services (numeric - decimal)
#
# -- PctOccupManu: percentage of people 16 and over who are employed in manufacturing (numeric - decimal) #### No longer sure
# of difference from PctEmplManu - may include unemployed manufacturing workers ####
#
# -- PctOccupMgmtProf: percentage of people 16 and over who are employed in management or professional occupations (numeric - decimal)
#
# -- MalePctDivorce: percentage of males who are divorced (numeric - decimal)
#
# -- MalePctNevMarr: percentage of males who have never married (numeric - decimal)
#
# -- FemalePctDiv: percentage of females who are divorced (numeric - decimal)
#
# -- TotalPctDiv: percentage of population who are divorced (numeric - decimal)
#
# -- PersPerFam: mean number of people per family (numeric - decimal)
#
# -- PctFam2Par: percentage of families (with kids) that are headed by two parents (numeric - decimal)
#
# -- PctKids2Par: percentage of kids in family housing with two parents (numeric - decimal)
#
# -- PctYoungKids2Par: percent of kids 4 and under in two parent households (numeric - decimal)
#
# -- PctTeen2Par: percent of kids age 12-17 in two parent households (numeric - decimal)
#
# -- PctWorkMomYoungKids: percentage of moms of kids 6 and under in labor force (numeric - decimal)
#
# -- PctWorkMom: percentage of moms of kids under 18 in labor force (numeric - decimal)
#
# -- NumKidsBornNeverMar: number of kids born to never married (numeric - expected to be integer)
#
# -- PctKidsBornNeverMar: percentage of kids born to never married (numeric - decimal)
#
# -- NumImmig: total number of people known to be foreign born (numeric - expected to be integer)
#
# -- PctImmigRecent: percentage of immigrants who immigated within last 3 years (numeric - decimal)
#
# -- PctImmigRec5: percentage of immigrants who immigated within last 5 years (numeric - decimal)
#
# -- PctImmigRec8: percentage of immigrants who immigated within last 8 years (numeric - decimal)
#
# -- PctImmigRec10: percentage of immigrants who immigated within last 10 years (numeric - decimal)
#
# -- PctRecentImmig: percent of population who have immigrated within the last 3 years (numeric - decimal)
#
# -- PctRecImmig5: percent of population who have immigrated within the last 5 years (numeric - decimal)
#
# -- PctRecImmig8: percent of population who have immigrated within the last 8 years (numeric - decimal)
#
# -- PctRecImmig10: percent of population who have immigrated within the last 10 years (numeric - decimal)
#
# -- PctSpeakEnglOnly: percent of people who speak only English (numeric - decimal)
#
# -- PctNotSpeakEnglWell: percent of people who do not speak English well (numeric - decimal)
#
# -- PctLargHouseFam: percent of family households that are large (6 or more) (numeric - decimal)
#
# -- PctLargHouseOccup: percent of all occupied households that are large (6 or more people) (numeric - decimal)
#
# -- PersPerOccupHous: mean persons per household (numeric - decimal)
#
# -- PersPerOwnOccHous: mean persons per owner occupied household (numeric - decimal)
#
# -- PersPerRentOccHous: mean persons per rental household (numeric - decimal)
#
# -- PctPersOwnOccup: percent of people in owner occupied households (numeric - decimal)
#
# -- PctPersDenseHous: percent of persons in dense housing (more than 1 person per room) (numeric - decimal)
# -- PctHousLess3BR: percent of housing units with less than 3 bedrooms (numeric - decimal)
#
# -- MedNumBR: median number of bedrooms (numeric - decimal)
#
# -- HousVacant: number of vacant households (numeric - expected to be integer)
#
# -- PctHousOccup: percent of housing occupied (numeric - decimal)
#
# -- PctHousOwnOcc: percent of households owner occupied (numeric - decimal)
# -- PctVacantBoarded: percent of vacant housing that is boarded up (numeric - decimal)
#
# -- PctVacMore6Mos: percent of vacant housing that has been vacant more than 6 months (numeric - decimal)
#
# -- MedYrHousBuilt: median year housing units built (numeric - may be integer)
#
# -- PctHousNoPhone: percent of occupied housing units without phone (in 1990, this was rare!) (numeric - decimal)
#
# -- PctWOFullPlumb: percent of housing without complete plumbing facilities (numeric - decimal)
#
# -- OwnOccLowQuart: owner occupied housing - lower quartile value (numeric - decimal)
#
# -- OwnOccMedVal: owner occupied housing - median value (numeric - decimal)
#
# -- OwnOccHiQuart: owner occupied housing - upper quartile value (numeric - decimal)
#
# -- OwnOccQrange: owner occupied housing - difference between upper quartile and lower quartile values (numeric - decimal)
#
# -- RentLowQ: rental housing - lower quartile rent (numeric - decimal)
#
# -- RentMedian: rental housing - median rent (Census variable H32B from file STF1A) (numeric - decimal)
#
# -- RentHighQ: rental housing - upper quartile rent (numeric - decimal)
#
# -- RentQrange: rental housing - difference between upper quartile and lower quartile rent (numeric - decimal)
#
# -- MedRent: median gross rent (Census variable H43A from file STF3A - includes utilities) (numeric - decimal)
#
# -- MedRentPctHousInc: median gross rent as a percentage of household income (numeric - decimal)
#
# -- MedOwnCostPctInc: median owners cost as a percentage of household income - for owners with a mortgage (numeric - decimal)
#
# -- MedOwnCostPctIncNoMtg: median owners cost as a percentage of household income - for owners without a mortgage (numeric - decimal)
#
# -- NumInShelters: number of people in homeless shelters (numeric - expected to be integer)
#
# -- NumStreet: number of homeless people counted in the street (numeric - expected to be integer)
#
# -- PctForeignBorn: percent of people foreign born (numeric - decimal)
#
# -- PctBornSameState: percent of people born in the same state as currently living (numeric - decimal)
#
# -- PctSameHouse85: percent of people living in the same house as in 1985 (5 years before) (numeric - decimal)
#
# -- PctSameCity85: percent of people living in the same city as in 1985 (5 years before) (numeric - decimal)
#
# -- PctSameState85: percent of people living in the same state as in 1985 (5 years before) (numeric - decimal)
#
# -- LemasSwornFT: number of sworn full time police officers (numeric - expected to be integer)
#
# -- LemasSwFTPerPop: sworn full time police officers per 100K population (numeric - decimal)
#
# -- LemasSwFTFieldOps: number of sworn full time police officers in field operations (on the street as opposed to
# administrative etc) (numeric - expected to be integer)
#
# -- LemasSwFTFieldPerPop: sworn full time police officers in field operations (on the street as opposed to administrative
# etc) per 100K population (numeric - decimal)
#
# -- LemasTotalReq: total requests for police (numeric - expected to be integer)
#
# -- LemasTotReqPerPop: total requests for police per 100K popuation (numeric - decimal)
#
# -- PolicReqPerOffic: total requests for police per police officer (numeric - decimal) -- PolicPerPop: police officers per 100K population (numeric - decimal)
#
# -- RacialMatchCommPol: a measure of the racial match between the community and the police force. High values indicate proportions in community and police force are similar (numeric - decimal)
#
#
# -- PctPolicWhite: percent of police that are caucasian (numeric - decimal)
#
# -- PctPolicBlack: percent of police that are african american (numeric - decimal)
#
# -- PctPolicHisp: percent of police that are hispanic (numeric - decimal)
#
# -- PctPolicAsian: percent of police that are asian (numeric - decimal)
#
# -- PctPolicMinor: percent of police that are minority of any kind (numeric - decimal)
#
# -- OfficAssgnDrugUnits: number of officers assigned to special drug units (numeric - expected to be integer)
#
# -- NumKindsDrugsSeiz: number of different kinds of drugs seized (numeric - expected to be integer)
#
# -- PolicAveOTWorked: police average overtime worked (numeric - decimal)
#
# -- LandArea: land area in square miles (numeric - decimal)
#
# -- PopDens: population density in persons per square mile (numeric - decimal)
#
# -- PctUsePubTrans: percent of people using public transit for commuting (numeric - decimal)
#
# -- PolicCars: number of police cars (numeric - expected to be integer)
#
# -- PolicOperBudg: police operating budget (numeric - may be integer)
#
# -- LemasPctPolicOnPatr: percent of sworn full time police officers on patrol (numeric - decimal)
#
# -- LemasGangUnitDeploy: gang unit deployed (numeric - integer - but really nominal - 0 means NO, 10 means YES, 5 means Part Time)
#
# -- LemasPctOfficDrugUn: percent of officers assigned to drug units (numeric - decimal)
#
# -- PolicBudgPerPop: police operating budget per population (numeric - decimal)
#
# -- murders: number of murders in 1995 (numeric - expected to be integer) potential GOAL attribute (to be predicted)
#
# -- murdPerPop: number of murders per 100K population (numeric - decimal) potential GOAL attribute (to be predicted) -- rapes: number of rapes in 1995 (numeric - expected to be integer) potential GOAL attribute (to be predicted)
#
# -- rapesPerPop: number of rapes per 100K population (numeric - decimal) potential GOAL attribute (to be predicted)
#
# -- robberies: number of robberies in 1995 (numeric - expected to be integer) potential GOAL attribute (to be predicted)
#
# -- robbbPerPop: number of robberies per 100K population (numeric - decimal) potential GOAL attribute (to be predicted)
#
# -- assaults: number of assaults in 1995 (numeric - expected to be integer) potential GOAL attribute (to be predicted)
#
# -- assaultPerPop: number of assaults per 100K population (numeric - decimal) potential GOAL attribute (to be predicted)
#
# -- burglaries: number of burglaries in 1995 (numeric - expected to be integer) potential GOAL attribute (to be predicted)
#
# -- burglPerPop: number of burglaries per 100K population (numeric - decimal) potential GOAL attribute (to be predicted)
#
# -- larcenies: number of larcenies in 1995 (numeric - expected to be integer) potential GOAL attribute (to be predicted)
#
# -- larcPerPop: number of larcenies per 100K population (numeric - decimal) potential GOAL attribute (to be predicted)
#
# -- autoTheft: number of auto thefts in 1995 (numeric - expected to be integer) potential GOAL attribute (to be predicted)
#
# -- autoTheftPerPop: number of auto thefts per 100K population (numeric - decimal) potential GOAL attribute (to be predicted)
#
# -- arsons: number of arsons in 1995 (numeric - expected to be integer) potential GOAL attribute (to be predicted)
#
# -- arsonsPerPop: number of arsons per 100K population (numeric - decimal) potential GOAL attribute (to be predicted)
#
# -- ViolentCrimesPerPop: total number of violent crimes per 100K popuation (numeric - decimal) GOAL attribute (to be
# predicted)
#
# -- nonViolPerPop: total number of non-violent crimes per 100K popuation (numeric - decimal) potential GOAL attribute (to be predicted)

# %% [markdown]
# # ```data analysis```

# %% [markdown]
# Lets check which US state has the highest median household income

# %%
# Group the data by state and calculate the median income for each state
median_income_by_state = data.groupby('state')['medIncome'].median().sort_values()

# Plotting
plt.figure(figsize=(10, 6))
median_income_by_state.plot(kind='bar', color='skyblue')
plt.title('Median Household Income by State')
plt.xlabel('State')
plt.ylabel('Median Household Income')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %% [markdown]
# Illinois 'IL' has the highest median household income among all the US states while Los Angeles 'LA' has the least median household income so the crime rate maybe higher in LA.

# %%
mean_poverty_percentage_by_state = data.groupby('state')['PctPopUnderPov'].mean().reset_index()

# Plotting the bar chart
plt.figure(figsize=(12, 6))
plt.bar(mean_poverty_percentage_by_state['state'], mean_poverty_percentage_by_state['PctPopUnderPov'], color='lightgreen')
plt.title('Mean Percentage of People Under the Poverty Level by State')
plt.xlabel('State')
plt.ylabel('Mean Percentage of People Under the Poverty Level')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %% [markdown]
# As expected , when we did the graph of the 'median household income'the results showed us that LA had the least median household income among all states , so it is expected that the poverty rate in this state is the highest. This will lead us to expect that the crime rate in LA will be the highest

# %%
# Plotting the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(data['PctLess9thGrade'], data['perCapInc'], color='skyblue', alpha=0.5)
plt.title('percentage of people 25 and over with less than a 9th grade education vs. Per Capita Income')
plt.xlabel('percentage of people 25 and over with less than a 9th grade education')
plt.ylabel('Per Capita Income')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plotting the hexbin plot
plt.figure(figsize=(10, 6))
plt.hexbin(data['PctLess9thGrade'], data['perCapInc'], gridsize=30, cmap='Blues')
plt.colorbar(label='Density')
plt.title('percentage of people 25 and over with less than a 9th grade education vs. Per Capita Income')
plt.xlabel('percentage of people 25 and over with less than a 9th grade education')
plt.ylabel('Per Capita Income')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plotting the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(data['PctNotHSGrad'], data['perCapInc'], color='skyblue', alpha=0.5)
plt.title('Percentage of People 25 and Over Not High School Graduates vs. Per Capita Income')
plt.xlabel('Percentage of People 25 and Over Not High School Graduates')
plt.ylabel('Per Capita Income')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plotting the hexbin plot
plt.figure(figsize=(10, 6))
plt.hexbin(data['PctNotHSGrad'], data['perCapInc'], gridsize=30, cmap='Blues')
plt.colorbar(label='Density')
plt.title('Percentage of People 25 and Over Not High School Graduates vs. Per Capita Income')
plt.xlabel('Percentage of People 25 and Over Not High School Graduates')
plt.ylabel('Per Capita Income')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plotting the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(data['PctBSorMore'], data['perCapInc'], color='skyblue', alpha=0.5)
plt.title('percentage of people 25 and over with a bachelors degree or higher education vs. Per Capita Income')
plt.xlabel('percentage of people 25 and over with a bachelors degree or higher education')
plt.ylabel('Per Capita Income')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plotting the hexbin plot
plt.figure(figsize=(10, 6))
plt.hexbin(data['PctBSorMore'], data['perCapInc'], gridsize=30, cmap='Blues')
plt.colorbar(label='Density')
plt.title('Percentage of People 25 and Over Not High School Graduates vs. Per Capita Income')
plt.xlabel('Percentage of People 25 and Over Not High School Graduates')
plt.ylabel('Per Capita Income')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Sort the DataFrame by the number of police officers
data = data.sort_values(by='LemasSwornFT', ascending=False)

plt.figure(figsize=(10, 6))
plt.bar(data['state'], data['LemasSwornFT'], color='red')
plt.xlabel('State')
plt.ylabel('Number of Police Officers')
plt.title('Number of Sworn Full-Time Police Officers in Each State')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.yticks([])  # Remove y-axis tick labels
plt.tight_layout()
plt.show()

# %% [markdown]
# WY 'Wyoming', ID 'Idaho', ND 'North Dakota' states seem to not have any sworn full time police officers , this means that these states are more likely to be attacked with criminals. These states should hire more full time police officers to help people if there is any criminal action

# %%
data['LemasTotalReq'] = pd.to_numeric(data['LemasTotalReq'], errors='coerce')
data['PctPolicWhite'] = pd.to_numeric(data['PctPolicWhite'], errors='coerce')
data['PctPolicBlack'] = pd.to_numeric(data['PctPolicBlack'], errors='coerce')
data['PctPolicHisp'] = pd.to_numeric(data['PctPolicHisp'], errors='coerce')
data['PctPolicAsian'] = pd.to_numeric(data['PctPolicAsian'], errors='coerce')
data['PctPolicMinor'] = pd.to_numeric(data['PctPolicMinor'], errors='coerce')
data['OfficAssgnDrugUnits'] = pd.to_numeric(data['OfficAssgnDrugUnits'], errors='coerce')
data['PolicCars'] = pd.to_numeric(data['PolicCars'], errors='coerce')
data['murders'] = pd.to_numeric(data['murders'], errors='coerce')
data['rapes'] = pd.to_numeric(data['rapes'], errors='coerce')
data['robberies'] = pd.to_numeric(data['robberies'], errors='coerce')
data['assaults'] = pd.to_numeric(data['assaults'], errors='coerce')
data['burglaries'] = pd.to_numeric(data['burglaries'], errors='coerce')
data['larcenies'] = pd.to_numeric(data['larcenies'], errors='coerce')
data['autoTheft'] = pd.to_numeric(data['autoTheft'], errors='coerce')
data['arsons'] = pd.to_numeric(data['arsons'], errors='coerce')

# %%
plt.figure(figsize=(15, 10))
sns.kdeplot(data=data, x='LemasTotalReq', hue='state', fill=True, multiple="stack")
plt.title('Total Requests for Police Distribution by State')
plt.xlabel('Total Requests for Police')
plt.ylabel('Density')
plt.tight_layout()
plt.show()

# %% [markdown]
# It seems like PA 'Pennsylvania' and NC 'North Carolina' , both have the highest requests for police , which means both have the highest percent of criminal attacks. Hiring more police men would be a good idea to cope with the multiple requests.

# %%
labels = ['White', 'Black', 'Hispanic', 'Asian', 'Other']
sizes = [data['PctPolicWhite'].mean(),
         data['PctPolicBlack'].mean(),
         data['PctPolicHisp'].mean(),
         data['PctPolicAsian'].mean(),
         data['PctPolicMinor'].mean()]

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=190)
plt.axis('equal')
plt.title('Racial Composition of Police Officers')
plt.show()

# %% [markdown]
# Percent of police that are caucasian ( white ) is the highest among all racial compositions.

# %%
# Calculate the percentage of officers from each racial group assigned to drug units
data['PctDrugUnitsBlack'] = data['OfficAssgnDrugUnits'] * data['PctPolicBlack'] / 100
data['PctDrugUnitsWhite'] = data['OfficAssgnDrugUnits'] * data['PctPolicWhite'] / 100
data['PctDrugUnitsHisp'] = data['OfficAssgnDrugUnits'] * data['PctPolicHisp'] / 100
data['PctDrugUnitsAsian'] = data['OfficAssgnDrugUnits'] * data['PctPolicAsian'] / 100
data['PctDrugUnitsMinor'] = data['OfficAssgnDrugUnits'] * data['PctPolicMinor'] / 100

racial_groups = ['Black', 'White', 'Hispanic', 'Asian', 'Minority']
percentages = [
    data['PctDrugUnitsBlack'].mean(),
    data['PctDrugUnitsWhite'].mean(),
    data['PctDrugUnitsHisp'].mean(),
    data['PctDrugUnitsAsian'].mean(),
    data['PctDrugUnitsMinor'].mean()
]

plt.figure(figsize=(10, 6))
plt.bar(racial_groups, percentages, color='skyblue')
plt.xlabel('Racial Group')
plt.ylabel('Percentage Assigned to Drug Units')
plt.title('Percentage of Police Officers Assigned to Drug Units by Racial Group')
plt.show()

# %% [markdown]
# White police officers have the highest percent of being assigned to drug units

# %%
# Group by state and calculate the sum of police cars
total_police_cars_per_state = data.groupby('state')['PolicCars'].sum().reset_index()

# Plotting
plt.figure(figsize=(10, 9))
sns.barplot(x='PolicCars', y='state', data=total_police_cars_per_state, palette='viridis')
plt.title('Total Number of Police Cars per State')
plt.xlabel('Total Number of Police Cars')
plt.ylabel('State')
plt.xticks(rotation=0)  # Rotate the y-axis labels to horizontal orientation
plt.tight_layout()
plt.show()

# %% [markdown]
# WY 'Wyoming' , ND 'North Dakota' , ID 'Idaho' , DE 'Delaware' don't have any police cars. There may be a rise in criminal activity due to the lack of law enforcement response. Also , the absence of police cars can make it challenging for authorities to respond to emergencies.

# %%
df_sorted = data.sort_values(by='murders', ascending=False)

plt.figure(figsize=(10, 8))
plt.bar(df_sorted['state'], df_sorted['murders'], color='purple')
plt.xlabel('States')
plt.ylabel('Number of Murders')
plt.title('States with the Highest Number of Murders')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# As we can see , NY 'New York' has got the highest number of murders which means that this state isn't a safe place , more cops should be hired , more police stations must be built

# %%
# Sort the DataFrame by both murders and rapes
data = data.sort_values(by=['murders', 'rapes'], ascending=False)

plt.figure(figsize=(10, 6))
plt.scatter(data['murders'], data['rapes'], color='blue', alpha=0.5)

# Highlight the state with the highest murders and rapes
plt.annotate(data['state'].iloc[0]  , (data['murders'].iloc[0], data['rapes'].iloc[0]), textcoords="offset points", xytext=(-10,1), ha='center', fontsize=8, fontweight='bold', color='red')

plt.xlabel('Murders')
plt.ylabel('Rapes')
plt.title('States with the Highest Murders and Rapes')
plt.grid(True)
plt.show()

# %% [markdown]
# NY 'New York' has the highest number of murders and rapes. Partols should be increased and number of police officers must be increased too.

# %%
# Summing up all the crime columns for each state
data['total_crimes'] = data[['murders', 'rapes', 'robberies', 'assaults', 'burglaries', 'larcenies', 'autoTheft', 'arsons']].sum(axis=1)



df_sorted = data.sort_values(by='total_crimes', ascending=False)



heatmap_data = df_sorted.pivot_table(index=None, columns='state', values='total_crimes')
plt.figure(figsize=(12, 8))
sns.heatmap(heatmap_data, cmap='Blues')
plt.title('Heatmap of Total Crimes by State')
plt.xlabel('State')
plt.ylabel('Total Crimes')
plt.tight_layout()
plt.show()

# %% [markdown]
# DC is the most dangerous state among all states , it has all the criminal actions with the highest numbers

# %% [markdown]
# # ```Data preprocessing and cleaning```

# %% [markdown]
# ## data set naming

# %%
df=pd.read_csv("crimes/crimes.csv")

# %%
# Open the file for reading columns names
with open('crimes/column_names.rtf', 'r') as file:
    # Read the lines
    lines = file.readlines()

# Process each line
processed_lines = []
for line in lines:
    # Split the line at ":"
    parts = line.split(':')

    # Keep only the part before ":" and after "--"
    processed_line = parts[0][5:]  #if len(parts) > 0 else line

    # Append the processed line to the list
    processed_lines.append(processed_line)

# Open the file for writing
with open('crimes/column_names_new.txt', 'w') as file:
    # Write the processed lines back to the file
    file.writelines(processed_lines)

# %%
# Get the current column names
new_cols = processed_lines
len(new_cols)
current_column_names = df.columns.tolist()
len(current_column_names)
# Out:
# 147

# %%
# Define a mapping for the new column names
new_column_names = {
    # current_column_names[0]: 'new_column_name1',
    # current_column_names[1]: 'new_column_name2',
    # Add more mappings as needed
}

for i in range(147):
    new_column_names[current_column_names[i]] = new_cols[i]

# Rename the columns
df = df.rename(columns=new_column_names)

df
# Out:
#            communityname state countyCode communityCode  fold  population  \
# 0         Marpletownship    PA         45         47616     1       23123
# 1             Tigardcity    OR          ?             ?     1       29344
# 2       Gloversvillecity    NY         35         29443     1       16656
# 3            Bemidjicity    MN          7          5068     1       11245
# 4        Springfieldcity    MO          ?             ?     1      140494
# ...                  ...   ...        ...           ...   ...         ...
# 2209          Mercedcity    CA          ?             ?    10       56216
# 2210       Pinevillecity    LA          ?             ?    10       12251
# 2211         Yucaipacity    CA          ?             ?    10       32824
# 2212        Beevillecity    TX          ?             ?    10       13547
# 2213  WestSacramentocity    CA          ?             ?    10       28898
#
#       householdsize  racepctblack  racePctWhite  racePctAsian  ...  \
# ...

# %% [markdown]
# ## feature selection

# %%
stats = pd.read_csv('crimes/stats.csv')
print("percentage of features with corr to violPerPop column  > 0.3: ", (abs(stats['Correlation w/ ViolPerPop']) > 0.3).sum() / 142 * 100, "%")
# Out:
# percentage of features with corr to violPerPop column  > 0.3:  35.2112676056338 %

# %% [markdown]
# ### colleration analysis

# %% [markdown]
# Correlation Interpretation:
#  Variables Highly Correlated with Violent Crime per Population (ViolPerPop):
#
#  **Positive Correlation**: Variables that show a significant positive correlation (greater than 0.5) with ViolPerPop include:
# pctBlack (0.628): A higher percentage of Black population correlates with a higher rate of violent crimes per population.
#
# pctPubAsst (0.563): A higher percentage of the population on public assistance is associated with more violent crimes.
#
# pctFemDivorc (0.537): Higher rates of divorced females in the population correlate with higher violent crime rates.
#
# pctAllDivorc (0.536): Similarly, higher overall divorce rates are associated with higher violent crime rates.
#
# pctMaleDivorc (0.510): Higher divorce rates among males also correlate with higher violent crime rates.
#
# pctUnemploy (0.483): Higher unemployment rates show a positive correlation with violent crime rates.
#
# pctNotHSgrad (0.468): A higher percentage of the population not graduating high school is associated with higher violent crime rates.
#
# pctLowEdu (0.371): Higher rates of lower education levels are associated with more violent crimes.
#
# pctLargHousFam (0.342): Larger household families are somewhat correlated with higher violent crime rates.
#
# pctKidsBornNevrMarr (0.738): A high percentage of children born to never-married individuals shows the strongest correlation with violent crimes per population.
#
# **Variables Negatively Correlated with Violent Crime per Population:**
#
# Negative Correlation: Variables showing a significant negative correlation (less than -0.5) with ViolPerPop include:
#
# pctWhite (-0.677): A higher percentage of White population correlates with a lower rate of violent crimes per population.
#
# pct2Par (-0.699): Higher percentages of two-parent households are associated with lower violent crime rates.
#
# pctKids2Par (-0.728): Similarly, higher percentages of children in two-parent households correlate with lower violent crime rates.
#
# pctKids-4w2Par (-0.658): Higher percentages of children aged -4 in two-parent households also show a negative correlation with violent crime rates.
#
# pct12-17w2Par (-0.656): Higher percentages of teenagers in two-parent households correlate with lower violent crime rates.
#
# **Variables with Low or Insignificant Correlation:**
#
# Variables such as perHoush, pctAsian, pct12-21, pct16-24, pct65up, persUrban, pctUrban, and medNumBedrm show low or negligible correlation with violent crimes per population. This suggests that these factors do not have a strong direct impact on violent crime rates when considered independently.
#
# **Variables Indicating Social and Economic Health:**
#
# The data suggests that communities with higher rates of unemployment, lower educational attainment, higher rates of public assistance, and higher rates of family disruption (e.g., divorce, children born to never-married parents) tend to have higher violent crime rates. Conversely, indicators of social stability such as higher rates of two-parent families and lower unemployment rates correlate with lower violent crime rates.
#
#  **Demographic Factors:**
#
# Demographic factors such as the racial composition of a community (higher percentages of Black or lower percentages of White populations) are strongly correlated with violent crime rates. However, it's crucial to approach these findings with an understanding of the broader socio-economic contexts that contribute to these correlations, rather than attributing causality directly to racial or ethnic backgrounds.

# %%
# removing non predictive data
df.drop('communityname', axis=1, inplace=True)
df.drop('state', axis=1, inplace=True)
df.drop('countyCode', axis=1, inplace=True)
df.drop('communityCode', axis=1, inplace=True)
df.drop('fold', axis=1, inplace=True)
df.replace('?', np.nan, inplace=True)
correlation_with_label = df.corr()['ViolentCrimesPerPop'].abs()  # Absolute correlation values

# Define the correlation threshold
correlation_threshold = 0.3  # Adjust as needed

# Get the names of columns to remove based on the correlation threshold
columns_to_remove = correlation_with_label[correlation_with_label < correlation_threshold].index.tolist()

# Remove the columns from the DataFrame
df.drop(columns=columns_to_remove, axis=1 ,inplace=True)


df
# Out:
#       racepctblack  racePctWhite  medIncome  pctWInvInc  pctWPubAsst  \
# 0             0.80         95.57      47917       64.11         2.75
# 1             0.74         94.33      35669       55.73         2.94
# 2             1.70         97.35      20580       38.95        11.71
# 3             0.53         89.16      17390       42.82        11.21
# 4             2.51         95.65      21577       41.15         7.12
# ...            ...           ...        ...         ...          ...
# 2209          6.87         61.68      24727       31.42        19.98
# 2210         21.18         76.65      20321       33.25         8.85
# 2211          0.52         92.62      27182       44.72         9.01
# 2212          3.37         69.91      19899       21.94        13.05
# 2213          2.39         71.27      23287       27.54        19.05
#
#       medFamInc  perCapInc  PctPopUnderPov  PctLess9thGrade  PctNotHSGrad  \
# ...

# %% [markdown]
# ## nulls

# %%
#to calculate null percentage in each column

stats['Missing %'] = stats['Missing'] / 2214 * 100
stats.to_csv('stats.csv', index=False)
stats
# Out:
#             variable   Minimum     Maximum          Mean  Standard Deviation  \
# 0                pop  10005.00  7322564.00  53117.984200       204620.252900
# 1           perHoush      1.60        5.28      2.707327            0.334120
# 2           pctBlack      0.00       96.67      9.335102           14.247156
# 3           pctWhite      2.68       99.63     83.979819           16.419080
# 4           pctAsian      0.03       57.46      2.670203            4.473843
# ..               ...       ...         ...           ...                 ...
# 137  autoTheftPerPop      6.55     4968.59    473.965628          504.666026
# 138           arsons      0.00     5119.00     30.907721          180.125248
# 139     arsonsPerPop      0.00      436.37     32.153682           39.240900
# 140    violentPerPop      0.00     4877.06    589.078922          614.784518
# 141    nonViolPerPop    116.79    27119.76   4908.241804         2739.708901
#
# ...

# %%
print("Percentage of features with over 80% missing data: ", ((stats['Missing %'] > 80).sum()) / len(stats) * 100, "%")
# Out:
# Percentage of features with over 80% missing data:  15.492957746478872 %

# %%
#droping columns with high null percentage
print("nulls before:", (df.isnull().mean().mean() * 100), "%")
df.drop('RacialMatchCommPol', axis=1, inplace=True)
df.drop('PctPolicWhite', axis=1, inplace=True)
df.drop('PctPolicBlack', axis=1, inplace=True)
df.drop('PctPolicMinor', axis=1, inplace=True)
df.drop('PolicCars', axis=1, inplace=True)
print("nulls after:", (df.isnull().mean().mean() * 100), "%")
# Out:
# nulls before: 9.231255645889792 %
# nulls after: 0.8672086720867207 %

# %%
cols = df.columns.tolist()
for i in cols:
    df[i] = pd.to_numeric(df[i], errors='coerce')
    df[i] = df[i].astype(float)
#replacing nulls with mean
for column in df.columns:
    if df[column].isnull().any():
        column_mean = df[column].mean()
        df[column].fillna(column_mean, inplace=True)
print("nulls:", (df.isnull().mean().mean() * 100), "%")
# Out:
# nulls: 0.0 %

# %% [markdown]
# nulls cleaning is complete next is transforming data to be ready for modeling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# %% [markdown]
# # ```Modeling```

# %% [markdown]
# ## preparing data for modelling

# %%
# Splitting data features & target colums
y= df. iloc[:, [43,44]]
z=df.drop(["ViolentCrimesPerPop"], axis=1)
x=z.drop(["nonViolPerPop"], axis=1)

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 1/3, random_state = 0)

# %% [markdown]
#  ## linear regression

# %%
# Fitting Simple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predicting the Test set results
y_pred = regressor.predict(X_test)

# %%
from sklearn import metrics
print("MSE:",metrics.mean_squared_error(y_pred,y_test))
print("MAE:",metrics.mean_absolute_error(y_pred,y_test))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_pred,y_test)))
print("r2_score:",metrics.r2_score(y_pred,y_test))
# Out:
# MSE: 0.053730152253283765
# MAE: 0.12500377442847707
# RMSE: 0.2317976536837329
# r2_score: 0.9453634691372028

# %% [markdown]
#  ##  gradient boosting

# %%
import xgboost as xgb
#Creating an XGBoost regressor
model = xgb.XGBRegressor()
#Training the model on the training data
model.fit(X_train, y_train)
#Making predictions on the test set
y_pred = model.predict(X_test)

# %%
print("MSE:",metrics.mean_squared_error(y_pred,y_test))
print("MAE:",metrics.mean_absolute_error(y_pred,y_test))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_pred,y_test)))
print("r2_score:",metrics.r2_score(y_pred,y_test))
# Out:
# MSE: 0.04508630624873394
# MAE: 0.08793078284896715
# RMSE: 0.21233536269009443
# r2_score: 0.9569020124157626

# %% [markdown]
#  ##  SVM

# %%
from sklearn.multioutput import MultiOutputRegressor
from sklearn.svm import SVR

model = MultiOutputRegressor(SVR(kernel = 'rbf'))
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
print("MSE:",metrics.mean_squared_error(y_pred,y_test))
print("MAE:",metrics.mean_absolute_error(y_pred,y_test))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_pred,y_test)))
print("r2_score:",metrics.r2_score(y_pred,y_test))
# Out:
# MSE: 0.10714193778755626
# MAE: 0.15180525411637713
# RMSE: 0.32732543101255707
# r2_score: 0.8764924591619823

# %% [markdown]
# # ```Credits:```
#
# This notebook is created by Connect X AI team.
# Directed by:
# AI team director Ammar Thabet
#
# Team leader:
# - Mazin mahmoud
#
# Team members:
# - Nadine Elkady
# - youssef khataan
# - Roaa
